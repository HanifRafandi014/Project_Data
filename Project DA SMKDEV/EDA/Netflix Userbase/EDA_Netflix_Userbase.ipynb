# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

path = '/content/drive/Shareddrives/Tugas Project SMKDEV Scholarship 2023/Kelompok 5/Netflix Userbase.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %%
df.duplicated().sum() #Checking whether the dataset have duplicated values
# Out:
# 0

# %%
df.nunique()
# Out:
# User ID              2500
# Subscription Type       3
# Monthly Revenue         6
# Join Date             300
# Last Payment Date      26
# Country                10
# Age                    26
# Gender                  2
# Device                  4
# Plan Duration           1
# dtype: int64

# %%
df["Plan Duration"].unique()
# Out:
# array(['1 Month'], dtype=object)

# %%
df = df.drop("Plan Duration", axis = 1) #Removing Plan Duration attribute as it only have 1 month in all columns

# %%
df['Join Date'] = pd.to_datetime(df['Join Date']) #Changing the datatype
df['Last Payment Date'] = pd.to_datetime(df['Last Payment Date']) #Changing the datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   datetime64[ns]
#  4   Last Payment Date  2500 non-null   datetime64[ns]
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
# dtypes: datetime64[ns](2), int64(3), object(4)
# memory usage: 175.9+ KB

# %%
df.isnull().sum()
# Out:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# dtype: int64

# %%
df.shape
# Out:
# (2500, 9)

# %%
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline

sub_cnts = df['Subscription Type'].value_counts()
px.pie(sub_cnts,
       names=sub_cnts.index,
       values=sub_cnts.values,
       title='Distribution of Subscription Types',
       color_discrete_sequence=px.colors.sequential.RdBu,
       hole = 0.5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6af310c1-c590-40db-8f1d-35bd1a8a2786" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6af310c1-c590-40db-8f1d-35bd1a8a2786")) {                    Plotly.newPlot(                        "6af310c1-c590-40db-8f1d-35bd1a8a2786",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"index=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Basic","Standard","Premium"],"legendgroup":"","name":"","showlegend":true,"values":[999,768,733],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}], ...

# %%
import seaborn as sns

sns.histplot(df['Age'], kde=True,
             kde_kws=dict(cut=3))
plt.title('Age Distribution of Netflix Users')
plt.show()

# %%
country_counts = df['Country'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(y=country_counts.index, x=country_counts.values, palette='RdBu')
plt.title('Country Distribution (Bar Chart)')
plt.xlabel('Count')
plt.ylabel('Country')
plt.xticks(rotation="vertical")
plt.show()

# %%
gender_counts = df['Gender'].value_counts()
px.pie(gender_counts, names=gender_counts.index,
       values=gender_counts.values,
       title='Gender Distribution',
       hole=0.5,
       color_discrete_sequence=px.colors.sequential.RdBu)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4d66ef13-1770-4ed6-b29f-a13a2e8e12cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d66ef13-1770-4ed6-b29f-a13a2e8e12cd")) {                    Plotly.newPlot(                        "4d66ef13-1770-4ed6-b29f-a13a2e8e12cd",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"index=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Female","Male"],"legendgroup":"","name":"","showlegend":true,"values":[1257,1243],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{" ...

# %%
px.box(df, x="Subscription Type", y="Age",
       color="Gender", notched=True,
       color_discrete_sequence=px.colors.sequential.Rainbow)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5b0854f1-7c63-4cbd-ac19-cb0f2d00523a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b0854f1-7c63-4cbd-ac19-cb0f2d00523a")) {                    Plotly.newPlot(                        "5b0854f1-7c63-4cbd-ac19-cb0f2d00523a",                        [{"alignmentgroup":"True","hovertemplate":"Gender=Male\u003cbr\u003eSubscription Type=%{x}\u003cbr\u003eAge=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male","marker":{"color":"rgb(150,0,90)"},"name":"Male","notched":true,"offsetgroup":"Male","orientation":"v","showlegend":true,"x":["Basic","Standard","Basic","Standard","Standard","Premium","Basic","Premium","Standard","Basic","Basic","Standard","Premium","Standard","Basic","Basic","Standard","Premium","Standard","Basic","Basic","Standard","Premium","Standard","Basic","Basic","Standard","Premium","Standard","Basic","Basic","Standard","Premium","Standard","Basic","Basic","Standard","Basic","Premium","Standard","Standard","Premium","Standard","Basic","Premium","Basic","Standard","Premium","Basic","Premium","Basic","Basic","Standard","Premium","Premium","Standard","Premium","Standard","Premium","Basic","Premium","Basic","Premium","Basic","Standard","Standard","Premium","Standard","Premium","Basic","Standard","Standard","Premium","Basic","Premium","Basic","Standard","Standard","Basic","Premium","Standard","Premium","Basic","Premium","Standard","Standard","Premium","Basic","Standard","Premium","Basic","Standard","Basic","Premium","Premium","Premium","Standard","Standard","Basic","Standard","Basic","Premium","Premium","Premium","Basic","Basic","Standard","Basic","Basic","Basic","Standard","Standard","Basic","Premium","Standard","Premium","Standard","Basic","Standard","Premium","Basic","Standard","Premium","Basic","Basic","Standard","Basic","Premium","Premium","Basic","Standard","Standard","Premium","Premium","Basic","Premium","Basic","Standard","Basic","Standard","Basic","Premium","Basic","Basic","Standard","Premium","Basic","Premium","Standard","Basic","Premium","Basic","Standard","Premium","Basic","Basic","Standard","Standard","Basic","Premium","Basic","Standard","Premium","Basic","Standard","Standard","Premium","Basic","Standard","Premium","Basic","Premium","Basic","Premium","Basic","Standard","Basic","Premium","Basic","Standard","Basic","Premium","Standard","Basic","Premium","Basic","Standard","Basic","Premium","Basic","Standard","Basic","Basic","Standard","Premium","Standard","Basic","Basic","Premium","Basic","Basic","Premium","Standard","Basic","Premium","Basic","Standard","Standard","Premium","Basic","Standard","Basic","Standard","Basic","Standard","Basic","Premium","Standard","Basic","Basic","Premium","Standard","Basic","Standard","Premium","Standard","Premium","Standard","Basic","Standard","Premium","Basic","Standard","Standard","Basic","Premium","Basic","Standard","Basic","Basic","Basic","Premium","Basic","Standard","Basic","Premium","Premium","Basic","Standard","Standard","Premium","Basic","Standard","Premium","Basic","Basic","Standard","Basic","Basic","Premium","Standard","Premium","Basic","Standard","Premium","Basic","Premium","Basic","Standard","Premium","Premium","Basic","Basic","Basic","Standard","Premium","Basic","Premium","Basic","Premium","Basic","Basic","Basic","Standard","Standard","Basic","Basic","Standard","Basic","Basic","Premium","Premium","Standard","Premium","Premium","Standard","Basic","Standard","Premium","Premium","Basic","Standard","Basic","Premium","Standard","Premium","Premium","Basic","Basic","Standard","Premium","Basic","Basic","Basic","Premium","Basic","Premium","Basic","Basic","Standard","Standard","Basic","Standard","Basic","Basic","Standard","Basic","Premium","Standard","Prem ...

# %%
fig = px.sunburst(df, path=["Country", "Subscription Type"],
                  values="Monthly Revenue",
                  title="Sunburst Chart with Text Labels")
fig.update_traces(textinfo="label+value+percent parent")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d375047c-b99f-4547-ab11-e16fd8e8759f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d375047c-b99f-4547-ab11-e16fd8e8759f")) {                    Plotly.newPlot(                        "d375047c-b99f-4547-ab11-e16fd8e8759f",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eMonthly Revenue=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Australia\u002fBasic","Brazil\u002fBasic","Canada\u002fBasic","France\u002fBasic","Germany\u002fBasic","Italy\u002fBasic","Mexico\u002fBasic","Spain\u002fBasic","United Kingdom\u002fBasic","United States\u002fBasic","Australia\u002fPremium","Brazil\u002fPremium","Canada\u002fPremium","France\u002fPremium","Germany\u002fPremium","Italy\u002fPremium","Spain\u002fPremium","United States\u002fPremium","Australia\u002fStandard","Brazil\u002fStandard","Canada\u002fStandard","Germany\u002fStandard","Italy\u002fStandard","Mexico\u002fStandard","Spain\u002fStandard","United Kingdom\u002fStandard","United States\u002fStandard","Australia","Brazil","Canada","France","Germany","Italy","Mexico","Spain","United Kingdom","United States"],"labels":["Basic","Basic","Basic","Basic","Basic","Basic","Basic","Basic","Basic","Basic","Premium","Premium","Premium","Premium","Premium","Premium","Premium","Premium","Standard","Standard","Standard","Standard","Standard","Standard","Standard","Standard","Standard","Australia","Brazil","Canada","France","Germany","Italy","Mexico","Spain","United Kingdom","United States"],"name":"","parents":["Australia","Brazil","Canada","France","Germany","Italy","Mexico","Spain","United Kingdom","United States","Australia","Brazil","Canada","France","Germany","Italy","Spain","United States","Australia","Brazil","Canada","Germany","Italy","Mexico","Spain","United Kingdom","United States","","","","","","","","","",""],"values":[378,1824,1816,445,1833,2223,46,1386,35,2483,1254,410,1086,1862,36,55,2689,1837,639,51,1048,391,39,2191,1587,2283,1344,2271,2285,3950,2307,2260,2317,2237,5662,2318,5664],"type":"sunburst","textinfo":"label+value+percent parent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[ ...

# %%
px.choropleth(df, locations="Country",
              locationmode="country names",
              color="Monthly Revenue",
              title="Choropleth Map of Monthly Revenue by Country")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fa2897f5-35a7-4e2b-a290-ee487d546932" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa2897f5-35a7-4e2b-a290-ee487d546932")) {                    Plotly.newPlot(                        "fa2897f5-35a7-4e2b-a290-ee487d546932",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"Country=%{location}\u003cbr\u003eMonthly Revenue=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"country names","locations":["United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United Kingdom","Australia","Germany","France","Brazil","Mexico","Spain","Italy","United States","Canada","United  ...

# %%
# Extract the year and month as a string for plotting
df['Join Month'] = df['Join Date'].dt.strftime('%Y-%m')
df['Last Payment Month'] = df['Last Payment Date'].dt.strftime('%Y-%m')

monthly_join_counts = df['Join Month'].value_counts().sort_index()
monthly_payment_counts = df['Last Payment Month'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
plt.plot(monthly_join_counts.index, monthly_join_counts.values,
         label='Join Date', marker='o')
plt.plot(monthly_payment_counts.index, monthly_payment_counts.values,
         label='Last Payment Date', marker='s')
plt.xlabel('Month')
plt.ylabel('Count')
plt.title('Monthly User Sign-ups and Last Payments')
plt.xticks(rotation="vertical")
plt.legend()
plt.show()
